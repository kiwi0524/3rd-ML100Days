# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現

# %%
import os
import keras

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若想使用可自行開啟)
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import tensorflow as tf

gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.5)

sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense
def build_mlp(input,output):
    """Code Here
    建立你的神經網路
    """
    model = Sequential()
    model.add(Dense(256,input_dim = input, activation='relu'))
    model.add(Dense(128,activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(output, activation='softmax'))
    return model

# %%
"""Code Here
設定超參數
"""

"""Code Here
設定超參數
"""
LR =[1e-4, 1e-3, 5e-3, 1e-2,5e-2,1e-1,5e-1]
epochs = 10
batch_size =256

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
from keras.optimizers import Adam
results = {}
for lr in LR:
    model = build_mlp(x_train.shape[1], y_train.shape[1])
    model.summary()
    model.compile(loss="categorical_crossentropy", optimizer=Adam(lr=lr), metrics=["accuracy"])
    model.fit(x_train, y_train, 
              epochs=epochs, 
              batch_size=batch_size, 
              validation_split=0.2, 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    
    results[lr] = {'train-loss': train_loss,'valid-loss': valid_loss, 'train-acc': train_acc, 'valid-acc': valid_acc}
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.9786 - accuracy: 0.2865 - val_loss: 1.8469 - val_accuracy: 0.3477
# Epoch 2/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.7765 - accuracy: 0.3765 - val_loss: 1.7595 - val_accuracy: 0.3829
# Epoch 3/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 1.7024 - accuracy: 0.4023 - val_loss: 1.7025 - val_accuracy: 0.4013
# Epoch 4/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 1.6543 - accuracy: 0.4182 - val_loss: 1.6904 - val_accuracy: 0.4073
# Epoch 5/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 1.6219 - accuracy: 0.4302 - val_loss: 1.6721 - val_accuracy: 0.4098
# Epoch 6/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 1.5943 - accuracy: 0.4389 - val_loss: 1.6311 - val_accuracy: 0.4269
# Epoch 7/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 1.5620 - accuracy: 0.4519 - val_loss: 1.5941 - val_accuracy: 0.4463
# Epoch 8/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 1.5362 - accuracy: 0.4626 - val_loss: 1.5789 - val_accuracy: 0.4487
# Epoch 9/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 1.5165 - accuracy: 0.4701 - val_loss: 1.6309 - val_accuracy: 0.4281
# Epoch 10/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.4978 - accuracy: 0.4740 - val_loss: 1.5537 - val_accuracy: 0.4550
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.9522 - accuracy: 0.2924 - val_loss: 1.8362 - val_accuracy: 0.3485
# Epoch 2/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 1.7521 - accuracy: 0.3732 - val_loss: 1.7428 - val_accuracy: 0.3748
# Epoch 3/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 1.6766 - accuracy: 0.3988 - val_loss: 1.6806 - val_accuracy: 0.4049
# Epoch 4/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.6086 - accuracy: 0.4253 - val_loss: 1.6347 - val_accuracy: 0.4223
# Epoch 5/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 1.5659 - accuracy: 0.4446 - val_loss: 1.5896 - val_accuracy: 0.4414
# Epoch 6/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 1.5287 - accuracy: 0.4559 - val_loss: 1.6149 - val_accuracy: 0.4295
# Epoch 7/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.4937 - accuracy: 0.4680 - val_loss: 1.6002 - val_accuracy: 0.4365
# Epoch 8/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 1.4750 - accuracy: 0.4756 - val_loss: 1.5473 - val_accuracy: 0.4534
# Epoch 9/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 1.4492 - accuracy: 0.4862 - val_loss: 1.5516 - val_accuracy: 0.4464
# Epoch 10/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.4369 - accuracy: 0.4888 - val_loss: 1.5055 - val_accuracy: 0.4711
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_39 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 2.2415 - accuracy: 0.2299 - val_loss: 1.9736 - val_accuracy: 0.2860
# Epoch 2/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 1.8524 - accuracy: 0.3288 - val_loss: 1.8607 - val_accuracy: 0.3174
# Epoch 3/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.7489 - accuracy: 0.3672 - val_loss: 1.7326 - val_accuracy: 0.3736
# Epoch 4/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.6931 - accuracy: 0.3876 - val_loss: 1.7270 - val_accuracy: 0.3841
# Epoch 5/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.6458 - accuracy: 0.4084 - val_loss: 1.6788 - val_accuracy: 0.3993
# Epoch 6/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 1.6120 - accuracy: 0.4194 - val_loss: 1.6713 - val_accuracy: 0.3985
# Epoch 7/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.5916 - accuracy: 0.4263 - val_loss: 1.7207 - val_accuracy: 0.3901
# Epoch 8/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.5590 - accuracy: 0.4363 - val_loss: 1.5849 - val_accuracy: 0.4330
# Epoch 9/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 1.5386 - accuracy: 0.4470 - val_loss: 1.6060 - val_accuracy: 0.4273
# Epoch 10/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 1.5131 - accuracy: 0.4577 - val_loss: 1.6444 - val_accuracy: 0.4168
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_44 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.9889 - accuracy: 0.1015 - val_loss: 2.3030 - val_accuracy: 0.0952
# Epoch 2/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 2.3028 - accuracy: 0.0991 - val_loss: 2.3026 - val_accuracy: 0.1014
# Epoch 3/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 2.3028 - accuracy: 0.1007 - val_loss: 2.3028 - val_accuracy: 0.1025
# Epoch 4/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3029 - accuracy: 0.0974 - val_loss: 2.3025 - val_accuracy: 0.1025
# Epoch 5/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3029 - accuracy: 0.0988 - val_loss: 2.3029 - val_accuracy: 0.0977
# Epoch 6/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 2.3031 - accuracy: 0.0966 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 7/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3029 - accuracy: 0.1005 - val_loss: 2.3029 - val_accuracy: 0.1003
# Epoch 8/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3030 - accuracy: 0.1005 - val_loss: 2.3032 - val_accuracy: 0.0977
# Epoch 9/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3031 - accuracy: 0.0974 - val_loss: 2.3029 - val_accuracy: 0.1016
# Epoch 10/10
# 40000/40000 [==============================] - 3s 74us/step - loss: 2.3031 - accuracy: 0.0984 - val_loss: 2.3029 - val_accuracy: 0.0980
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_47 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 16.8913 - accuracy: 0.1002 - val_loss: 2.3029 - val_accuracy: 0.1014
# Epoch 2/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3033 - accuracy: 0.0998 - val_loss: 2.3041 - val_accuracy: 0.0997
# Epoch 3/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 2.3038 - accuracy: 0.1002 - val_loss: 2.3036 - val_accuracy: 0.0952
# Epoch 4/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 2.3038 - accuracy: 0.0989 - val_loss: 2.3037 - val_accuracy: 0.1022
# Epoch 5/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3039 - accuracy: 0.0994 - val_loss: 2.3036 - val_accuracy: 0.1003
# Epoch 6/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3043 - accuracy: 0.0986 - val_loss: 2.3052 - val_accuracy: 0.0980
# Epoch 7/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3043 - accuracy: 0.0982 - val_loss: 2.3047 - val_accuracy: 0.1021
# Epoch 8/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3039 - accuracy: 0.1006 - val_loss: 2.3052 - val_accuracy: 0.1022
# Epoch 9/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 2.3044 - accuracy: 0.1000 - val_loss: 2.3039 - val_accuracy: 0.1022
# Epoch 10/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3048 - accuracy: 0.0986 - val_loss: 2.3046 - val_accuracy: 0.1014
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_51 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_52 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 64.8959 - accuracy: 0.1000 - val_loss: 2.3041 - val_accuracy: 0.0977
# Epoch 2/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3039 - accuracy: 0.0998 - val_loss: 2.3030 - val_accuracy: 0.1022
# Epoch 3/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3047 - accuracy: 0.1007 - val_loss: 2.3053 - val_accuracy: 0.1014
# Epoch 4/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3055 - accuracy: 0.0968 - val_loss: 2.3047 - val_accuracy: 0.0952
# Epoch 5/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3046 - accuracy: 0.0989 - val_loss: 2.3065 - val_accuracy: 0.1003
# Epoch 6/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3057 - accuracy: 0.0998 - val_loss: 2.3059 - val_accuracy: 0.0980
# Epoch 7/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3063 - accuracy: 0.1001 - val_loss: 2.3042 - val_accuracy: 0.1014
# Epoch 8/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3061 - accuracy: 0.0984 - val_loss: 2.3069 - val_accuracy: 0.1016
# Epoch 9/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3061 - accuracy: 0.0975 - val_loss: 2.3054 - val_accuracy: 0.1025
# Epoch 10/10
# 40000/40000 [==============================] - 3s 75us/step - loss: 2.3060 - accuracy: 0.0998 - val_loss: 2.3044 - val_accuracy: 0.0997
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_53 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_54 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_55 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_56 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 29864.3699 - accuracy: 0.0996 - val_loss: 2.3099 - val_accuracy: 0.1003
# Epoch 2/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3097 - accuracy: 0.0991 - val_loss: 2.3102 - val_accuracy: 0.1014
# Epoch 3/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3117 - accuracy: 0.1004 - val_loss: 2.3151 - val_accuracy: 0.0980
# Epoch 4/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3096 - accuracy: 0.0998 - val_loss: 2.3203 - val_accuracy: 0.0977
# Epoch 5/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 2.3135 - accuracy: 0.1007 - val_loss: 2.3149 - val_accuracy: 0.0977
# Epoch 6/10
# 40000/40000 [==============================] - 3s 77us/step - loss: 2.3165 - accuracy: 0.1017 - val_loss: 2.3120 - val_accuracy: 0.1003
# Epoch 7/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3158 - accuracy: 0.0996 - val_loss: 2.3150 - val_accuracy: 0.0980
# Epoch 8/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3168 - accuracy: 0.1003 - val_loss: 2.3156 - val_accuracy: 0.1016
# Epoch 9/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3163 - accuracy: 0.1029 - val_loss: 2.3081 - val_accuracy: 0.0980
# Epoch 10/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.3184 - accuracy: 0.0999 - val_loss: 2.3133 - val_accuracy: 0.1025

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

import matplotlib.pyplot as plt
# %matplotlib inline 
    
#NUM_COLORS = len(results.keys())
#cm = plt.get_cmap('gist_rainbow')
#color_bar = [cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)]

#plt.figure(figsize=(8,6))
for i, j in enumerate(results.keys()):
    plt.plot(range(len(results[j]['train-loss'])),results[j]['train-loss'], '-', label=j)
    plt.plot(range(len(results[j]['valid-loss'])),results[j]['valid-loss'], '--', label=j)
plt.title("Loss vs. Learning Rate")
plt.legend(loc=4)
plt.show()

plt.figure(figsize=(8,6))
for i, j in enumerate(results.keys()):
    plt.plot(range(len(results[j]['train-acc'])),results[j]['train-acc'], '-', label=j)
    plt.plot(range(len(results[j]['valid-acc'])),results[j]['valid-acc'], '--', label=j)
plt.title("Accuracy vs. Learning Rate")
plt.legend(loc=4)
plt.show()
